# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder \
    .appName("StudentTutorial") \
    .getOrCreate()


spark
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 spark = SparkSession.builder \
#       2     .appName("StudentTutorial") \
# ----> 3     .getOrCreate()
#       4
#       5
#       6 spark
#
# File ~/Desktop/PythonCourse/ai-ml-course/lesson17/.venv/lib/python3.14/site-packages/pyspark/sql/session.py:557, in SparkSession.Builder.getOrCreate(self)
#     555     sparkConf.set(key, value)
#     556 # This SparkContext may be an existing one.
# --> 557 sc = SparkContext.getOrCreate(sparkConf)
#     558 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     559 # by all sessions.
#     560 session = SparkSession(sc, options=self._options)
#
# File ~/Desktop/PythonCourse/ai-ml-course/lesson17/.venv/lib/python3.14/site-packages/pyspark/core/context.py:542, in SparkContext.getOrCreate(cls, conf)
#     540 with SparkContext._lock:
# ...
